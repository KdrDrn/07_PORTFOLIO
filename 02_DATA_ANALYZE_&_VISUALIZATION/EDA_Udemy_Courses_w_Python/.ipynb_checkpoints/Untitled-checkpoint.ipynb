# %% [markdown]
# # <h1 style="text-align: center;" class="list-group-item list-group-item-action active" data-toggle="list" role="tab" aria-controls="home">EDA of Udemy Courses</h1>

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters

from pylab import rcParams
sns.set_style("darkgrid")

import warnings
warnings.filterwarnings("ignore")

# %%
import plotly.io as pio
pio.renderers.default = 'iframe'

import plotly 
import plotly.express as px
import plotly.graph_objs as go
import plotly.offline as py
from plotly.offline import iplot
from plotly.subplots import make_subplots
import plotly.figure_factory as ff

# %% [markdown]
# ## Load and Read the Dataset

# %%
df0 = pd.read_csv("udemy_courses.csv")
df = df0.copy()

# %% [markdown]
# ## Data Exploring

# %%
df.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
df.sample(5)
# Out:
#       course_id                                       course_title  \
# 2109     771880                     Clarinet Lessons For Beginners
# 3410     916902   The Complete E-Commerce Web Developer Course 5.0
# 2401    1234656                              4 Week Rhythm Mastery
# 3635     576054  WordPress Development - Themes, Plugins & Sing...
# 680      648174                  Buchführung lernen leicht gemacht
#
#                                                     url  is_paid  price  \
# 2109  https://www.udemy.com/the-music-coach-online-c...     True     95
# 3410  https://www.udemy.com/e-commerce-web-developer...     True    195
# 2401       https://www.udemy.com/4-week-rhythm-mastery/     True     20
# 3635  https://www.udemy.com/wordpress-development-cr...     True    150
# 680   https://www.udemy.com/buchfuehrung-lernen-leic...     True     40
#
#       num_subscribers  num_reviews  num_lectures               level  \
# ...

# %%
df.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
df.columns

# df.keys()
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject', 'date'],
#       dtype='object')

# %%
df.shape
# Out:
# (3678, 12)

# %%
len(df)
# Out:
# 3678

# %%
df.size
# Out:
# 47814

# %%
# 3678 kursumuz var ve bunlara ait 12 feature, 12 ayrı bilgi var.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3678 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3678 non-null   int64
#  1   course_title         3678 non-null   object
#  2   url                  3678 non-null   object
#  3   is_paid              3678 non-null   bool
#  4   price                3678 non-null   int64
#  5   num_subscribers      3678 non-null   int64
#  6   num_reviews          3678 non-null   int64
#  7   num_lectures         3678 non-null   int64
#  8   level                3678 non-null   object
#  9   content_duration     3678 non-null   float64
#  10  published_timestamp  3678 non-null   object
#  11  subject              3678 non-null   object
# dtypes: bool(1), float64(1), int64(5), object(5)
# memory usage: 319.8+ KB

# %%
# temiz bir data olduğunu görüyoruz. data type larında bizi rahatsız eden data type var mı?
# published_timestamp, datetime tipinde olması daha uygun olur.
# url ile ilgili bir çalışmam olmayacaksa düşürülebilir,
# course_id lerinin indeks olması rahatsız edici. Bu haliyle işimize yaramayacaktır. bunu değiştirebiliriz.
# bizi rahatsız eden bir kodlama var mı. bak. null values. int olması gerekirken object olan var mı

# %%
df.isnull().sum()

# temiz bir data gibi gözüküyor.
# Out:
# course_id              0
# course_title           0
# url                    0
# is_paid                0
# price                  0
# num_subscribers        0
# num_reviews            0
# num_lectures           0
# level                  0
# content_duration       0
# published_timestamp    0
# subject                0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 6

# %%
df[df.duplicated()]
# Out:
#       course_id                                       course_title  \
# 787      837322  Essentials of money value: Get a financial Life !
# 788     1157298  Introduction to Forex Trading Business For Beg...
# 894     1035638                 Understanding Financial Statements
# 1100    1084454                  CFA Level 2- Quantitative Methods
# 1473     185526                             MicroStation - Células
# 2561      28295  Learn Web Designing & HTML5/CSS3 Essentials in...
#
#                                                     url  is_paid  price  \
# 787    https://www.udemy.com/essentials-of-money-value/     True     20
# 788   https://www.udemy.com/introduction-to-forex-tr...     True     20
# 894   https://www.udemy.com/understanding-financial-...     True     25
# 1100  https://www.udemy.com/cfa-level-2-quantitative...     True     40
# 1473        https://www.udemy.com/microstation-celulas/     True     20
# ...

# %%
df.describe()
# Out:
#           course_id        price  num_subscribers   num_reviews  num_lectures  \
# count  3.678000e+03  3678.000000      3678.000000   3678.000000   3678.000000
# mean   6.759720e+05    66.049483      3197.150625    156.259108     40.108755
# std    3.432732e+05    61.005755      9504.117010    935.452044     50.383346
# min    8.324000e+03     0.000000         0.000000      0.000000      0.000000
# 25%    4.076925e+05    20.000000       111.000000      4.000000     15.000000
# 50%    6.879170e+05    45.000000       911.500000     18.000000     25.000000
# 75%    9.613555e+05    95.000000      2546.000000     67.000000     45.750000
# max    1.282064e+06   200.000000    268923.000000  27445.000000    779.000000
#
#        content_duration
# count       3678.000000
# mean           4.094517
# std            6.053840
# min            0.000000
# 25%            1.000000
# 50%            2.000000
# 75%            4.500000
# max           78.500000

# %%
def data_describe_num(col):
    print('Count       :', len(df[col]))
    print('Mean        :', np.mean(df[col]))
    print('Std         :', np.std(df[col]))
    print('Min         :', np.min(df[col]))
    print('Q1          :', np.percentile(df[col], 25))
    print('Median(Q2)  :', np.median(df[col]))
    print('Q3          :', np.percentile(df[col], 75))
    print('Max         :', np.max(df[col]))

# %%
df.describe(include=object)
# Out:
#                          course_title  \
# count                            3678
# unique                           3663
# top     Acoustic Blues Guitar Lessons
# freq                                3
#
#                                                       url       level  \
# count                                                3678        3678
# unique                                               3672           4
# top     https://www.udemy.com/cfa-level-2-quantitative...  All Levels
# freq                                                    2        1929
#
#          published_timestamp          subject
# count                   3678             3678
# unique                  3672                4
# top     2017-07-02T14:29:35Z  Web Development
# freq                       2             1200

# %%
def data_describe_obj(col):
    print('Count       :', len(df[col]))
    print('Unique      :', df[col].nunique()) 
    print('Top         :', np.array(df.title.value_counts()[:1].index[0]))
    print('Frequency   :', np.array(df.title.value_counts()[:1].values[0]))

# %%
df.describe(include=bool)
# Out:
#        is_paid
# count     3678
# unique       2
# top       True
# freq      3368

# %%
df.nunique()
# Out:
# course_id              3672
# course_title           3663
# url                    3672
# is_paid                   2
# price                    38
# num_subscribers        2197
# num_reviews             511
# num_lectures            229
# level                     4
# content_duration        105
# published_timestamp    3672
# subject                   4
# date                   3672
# dtype: int64

# %%
df["date"] = pd.to_datetime(df["published_timestamp"])

# published_timestamp ı datetime yaparak date adında bir sütun yaptım.

# %%
df_1 = df.drop(["course_id", "url", "published_timestamp"], axis = 1).copy()

# %%
# "course_id" sini gereksiz görmüştük, "url"ler ile çalışmayacağız ve 
# "published_timestamp" yerine "date" sütunu oluşturduğum için artık ona ihtiyacım yok.
# bunları düşürüyorum.

# %%
df_1.sample(5)
# Out:
#                                            course_title  is_paid  price  \
# 325   Risk Analysis - Capital Budgeting for CA / CS ...     True     20
# 1047  Estrategias de Inversión aplicadas al mundo de...     True     20
# 1249  Foundation Skills on Adobe Illustrator: Learn ...     True     50
# 1539        How to Make a Custom Graphic From Sketches      True     20
# 1821                  Bass Guitar Lessons For Beginners     True     95
#
#       num_subscribers  num_reviews  num_lectures           level  \
# 325              2268            4            47      All Levels
# 1047                9            2            25      All Levels
# 1249             2489           39            16  Beginner Level
# 1539               21            4            17  Beginner Level
# 1821              180           21            38  Beginner Level
#
#       content_duration              subject                      date
# 325           5.500000     Business Finance 2015-07-07 20:21:29+00:00
# ...

# %%
df_1.describe()
# Out:
#              price  num_subscribers   num_reviews  num_lectures  \
# count  3678.000000      3678.000000   3678.000000   3678.000000
# mean     66.049483      3197.150625    156.259108     40.108755
# std      61.005755      9504.117010    935.452044     50.383346
# min       0.000000         0.000000      0.000000      0.000000
# 25%      20.000000       111.000000      4.000000     15.000000
# 50%      45.000000       911.500000     18.000000     25.000000
# 75%      95.000000      2546.000000     67.000000     45.750000
# max     200.000000    268923.000000  27445.000000    779.000000
#
#        content_duration
# count       3678.000000
# mean           4.094517
# std            6.053840
# min            0.000000
# 25%            1.000000
# 50%            2.000000
# 75%            4.500000
# max           78.500000

# %% [raw]
# Price feature'u incelendiğinde:
#
# mean ile median'a baktığımızda mean'in çok daha yüksek olduğunu görüyoruz. Yani verilerin yoğunluğu ve ağırlığı sağ tarafta toplanmış, bu toplanma mean'i tam ortadaki veriye (median'a) göre sağa çekmiş demektir bu.
#
# Demek ki sağa doğru (pozitif yönde) skewed diyebiliriz.
#
# Q1 ve Q3 e baktığımızda baya bir yayılma olduğunu görüyoruz. Zaten mean ile median arasındaki farktan da yayılmanın olduğunu söyleyebiliriz.
#
# sample size küçük değil, büyük. böyle büyük bir sample'da standard deviation değeri bir iki outlier ile çok artmaz.

# %% [raw]
# num_subscribers:
#
# 3678 kurs görüyoruz. bunların bazıların 0 kişi katılmış. maksimum olarak da bir kursa 2546 kişi katıldığını görüyoruz. kursların revaçta olma durumuna göre dağılımın çok arttığını görüyoruz. Bu yüzden standard deviation çok yüksek. dolayısıyla mean ile median arasındaki farkın da çok yüksek olduğunu görüyoruz.
#
# demek ki Udemy, sadece popülaritesi yüksek olan kursları seçmemiş, çok geniş yelpazede bir kurs sunmuş ki bazı kurslar hiç tercih edilmemesine rağmen bazıları çok çok fazla tercih edilmiş ve num_subscribers Q1 ve Q3 değeri arasında ve min ile max arasında çok fark çıkmış.

# %% [raw]
# num_reviews:
#
# mean medianın neredeyse 9 katı. sağa doğru skewed olduğunu anlıyoruz. standard deviation da büyük olmuş.

# %% [raw]
# standart dev. çok yüksekse ortalama değer benim için çok kullanışlı değildir. bu durumda ben median ile çalışırım. ilerde missing values doldurmak istediğimizde mean ile doldurmak mantıklı olmaz. median üzerinden gitmekte fayda var.

# %%
df_1.describe(exclude=np.number)
# Out:
#                          course_title is_paid       level          subject  \
# count                            3678    3678        3678             3678
# unique                           3663       2           4                4
# top     Acoustic Blues Guitar Lessons    True  All Levels  Web Development
# freq                                3    3368        1929             1200
# first                             NaN     NaN         NaN              NaN
# last                              NaN     NaN         NaN              NaN
#
#                              date
# count                        3678
# unique                       3672
# top     2017-07-02 14:29:35+00:00
# freq                            2
# first   2011-07-09 05:43:31+00:00
# last    2017-07-06 21:46:30+00:00

# %%
#  describe() bilgilerinin dağılımını görmek istiyorum. histogram plot bunları için uygun

# %%
# pandas ile histogram:

df_1.hist('price');

# %%
sns.histplot(data=df1, x='price', kde=True)
# Out:
# <AxesSubplot:xlabel='price', ylabel='Count'>

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3678 entries, 0 to 3677
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   course_title      3678 non-null   object
#  1   is_paid           3678 non-null   bool
#  2   price             3678 non-null   int64
#  3   num_subscribers   3678 non-null   int64
#  4   num_reviews       3678 non-null   int64
#  5   num_lectures      3678 non-null   int64
#  6   level             3678 non-null   object
#  7   content_duration  3678 non-null   float64
#  8   subject           3678 non-null   object
#  9   date              3678 non-null   datetime64[ns, UTC]
# dtypes: bool(1), datetime64[ns, UTC](1), float64(1), int64(4), object(3)
# memory usage: 262.3+ KB

# %%
df_1["subject"].value_counts(dropna=False)
# Out:
# Web Development        1200
# Business Finance       1195
# Musical Instruments     680
# Graphic Design          603
# Name: subject, dtype: int64

# %%
df_1["level"].value_counts(dropna=False)
# Out:
# All Levels            1929
# Beginner Level        1270
# Intermediate Level     421
# Expert Level            58
# Name: level, dtype: int64

# %%
# ANALYSIS

# %%
plt.figure(figsize = (15,5))
sns.histplot(data = df_1, x ="price", kde = True, bins = 10)
plt.title("Price Count", fontsize = 15)

plt.show()

# %%
fig = px.histogram(data_frame = df_1, x = "price", marginal = "box")
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_30.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
plt.figure(figsize = (15,5))
sns.histplot(data = df_1, x ="num_subscribers", kde = True, bins = 100)
plt.title("Number of Sucsribers Count", fontsize = 15)

plt.show()

# %%
fig = px.histogram(data_frame = df_1, x = "num_subscribers", marginal = "box")
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_32.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
plt.figure(figsize = (15,5))
sns.histplot(data = df_1, x ="num_reviews", kde = True, bins = 100)
plt.title("Number of Reviews Count", fontsize = 15)

plt.show()

# %%
fig = px.histogram(data_frame = df_1, x = "num_reviews", marginal = "box")
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_34.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
plt.figure(figsize = (15,5))
sns.histplot(data = df_1, x ="num_lectures", kde = True, bins = 100)
plt.title("Number of Lectures Count", fontsize = 15)

plt.show()

# %%
fig = px.histogram(data_frame = df_1, x = "num_lectures", marginal = "box")
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_36.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
df_1.describe()
# Out:
#              price  num_subscribers   num_reviews  num_lectures  \
# count  3678.000000      3678.000000   3678.000000   3678.000000
# mean     66.049483      3197.150625    156.259108     40.108755
# std      61.005755      9504.117010    935.452044     50.383346
# min       0.000000         0.000000      0.000000      0.000000
# 25%      20.000000       111.000000      4.000000     15.000000
# 50%      45.000000       911.500000     18.000000     25.000000
# 75%      95.000000      2546.000000     67.000000     45.750000
# max     200.000000    268923.000000  27445.000000    779.000000
#
#        content_duration
# count       3678.000000
# mean           4.094517
# std            6.053840
# min            0.000000
# 25%            1.000000
# 50%            2.000000
# 75%            4.500000
# max           78.500000

# %%
plt.figure(figsize = (15,5))
sns.histplot(data = df_1, x ="content_duration", kde = True, bins = 100)
plt.title("Content Duration Count", fontsize = 15)

plt.show()

# %%
fig = px.histogram(data_frame = df_1, x = "content_duration", marginal = "box")
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_39.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
df_1.corr()
# Out:
#                    is_paid     price  num_subscribers  num_reviews  \
# is_paid           1.000000  0.328513        -0.266159    -0.087471
# price             0.328513  1.000000         0.050769     0.113696
# num_subscribers  -0.266159  0.050769         1.000000     0.649946
# num_reviews      -0.087471  0.113696         0.649946     1.000000
# num_lectures      0.112574  0.330160         0.157746     0.243029
# content_duration  0.094417  0.293450         0.161839     0.228889
#
#                   num_lectures  content_duration
# is_paid               0.112574          0.094417
# price                 0.330160          0.293450
# num_subscribers       0.157746          0.161839
# num_reviews           0.243029          0.228889
# num_lectures          1.000000          0.801647
# content_duration      0.801647          1.000000

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df_1.corr(), annot = True, cmap = "magma");

# %%
fig = px.imshow(df_1.corr())
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_42.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
sns.pairplot(df_1,corner = True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\numpy\lib\histograms.py:351, in _unsigned_subtract(a, b)
#     350 try:
# --> 351     dt = signed_to_unsigned[dt.type]
#     352 except KeyError:
#
# KeyError: <class 'numpy.bool_'>
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 sns.pairplot(df_1,corner = True)
#       2 plt.show()
#
# File ~\anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
# ...

# %%
index_vals = df['level'].astype('category').cat.codes
fig = go.Figure(data=go.Splom(
                dimensions=[dict(label='price',
                                 values=df_1['price']),
                            dict(label='num_subscribers',
                                 values=df_1['num_subscribers']),
                            dict(label='num_reviews',
                                 values=df_1['num_reviews']),
                            dict(label='num_lectures',
                                 values=df_1['num_lectures']),
                           dict(label='content_duration',
                                 values=df_1['content_duration'])],
                showupperhalf=False, 
                text=df_1['level'],
                marker=dict(color=index_vals,
                            showscale=False, # colors encode categorical variables
                            line_color='white', line_width=0.5)
                ))


fig.update_layout(
    title='UDEMY Courses',
    width=1000,
    height=1000,
)

fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="1020px"
#     height="1020"
#     src="iframe_figures/figure_43.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
df_1["subject"].value_counts()
# Out:
# Web Development        1200
# Business Finance       1195
# Musical Instruments     680
# Graphic Design          603
# Name: subject, dtype: int64

# %%
np.round(df_1["subject"].value_counts(normalize=True),2)
# Out:
# Web Development        0.33
# Business Finance       0.32
# Musical Instruments    0.18
# Graphic Design         0.16
# Name: subject, dtype: float64

# %%
fig = px.histogram(df_1, x="subject", title='Course Count by Subject')
fig.update_layout(xaxis={'categoryorder':'total descending'})
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_47.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
df_1["year"]= df_1["date"].dt.year
subject_by_year = df_1.groupby("year")["subject"].value_counts().reset_index(level=0).rename(columns={"subject": "subject count"}, index={'index': 'Subject'})
subject_by_year
# Out:
#                      year  subject count
# subject
# Web Development      2011              5
# Web Development      2012             19
# Graphic Design       2012             10
# Musical Instruments  2012             10
# Business Finance     2012              6
# Business Finance     2013             84
# Web Development      2013             56
# Musical Instruments  2013             39
# Graphic Design       2013             23
# Business Finance     2014            192
# Musical Instruments  2014            120
# Web Development      2014            113
# Graphic Design       2014             66
# Business Finance     2015            339
# Web Development      2015            336
# Musical Instruments  2015            171
# Graphic Design       2015            168
# Web Development      2016            448
# Business Finance     2016            349
# Musical Instruments  2016            228
# Graphic Design       2016            181
# Business Finance     2017            225
# ...

# %%
fig = px.line(subject_by_year, x="year", y="subject count", color= subject_by_year.index, title="UDEMY Courses By Subject in Each Year")
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_50.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
df_1["level"].value_counts()
# Out:
# All Levels            1929
# Beginner Level        1270
# Intermediate Level     421
# Expert Level            58
# Name: level, dtype: int64

# %%
sns.histplot(data = df_1, x = df_1["level"])
plt.show()

# %%
df_1.head()
# Out:
#                                         course_title  is_paid  price  \
# 0                 Ultimate Investment Banking Course     True    200
# 1  Complete GST Course & Certification - Grow You...     True     75
# 2  Financial Modeling for Business Analysts and C...     True     45
# 3  Beginner to Pro - Financial Analysis in Excel ...     True     95
# 4       How To Maximize Your Profits Trading Options     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# 1             2792          923           274          All Levels
# 2             2174           74            51  Intermediate Level
# 3             2451           11            36          All Levels
# 4             1276           45            26  Intermediate Level
#
#    content_duration           subject                      date  year
# 0               1.5  Business Finance 2017-01-18 20:58:58+00:00  2017
# ...

# %%
df_2 = df_1[["course_title", "num_subscribers", "subject", "year"]]
df_2
# Out:
#                                            course_title  num_subscribers  \
# 0                    Ultimate Investment Banking Course             2147
# 1     Complete GST Course & Certification - Grow You...             2792
# 2     Financial Modeling for Business Analysts and C...             2174
# 3     Beginner to Pro - Financial Analysis in Excel ...             2451
# 4          How To Maximize Your Profits Trading Options             1276
# ...                                                 ...              ...
# 3673  Learn jQuery from Scratch - Master of JavaScri...             1040
# 3674  How To Design A WordPress Website With No Codi...              306
# 3675                      Learn and Build using Polymer              513
# 3676  CSS Animations: Create Amazing Effects on Your...              300
# 3677  Using MODX CMS to Build Websites: A Beginner's...              901
#
#                subject  year
# 0     Business Finance  2017
# 1     Business Finance  2017
# ...

# %%
bottom_15 = df_2.sort_values(by="num_subscribers").head(15)
bottom_15
# Out:
#                                           course_title  num_subscribers  \
# 885                               beginning accounting                0
# 456  Introduction to Project Management for Finance...                0
# 457              Best Practices in Corporate Budgeting                0
# 458                Financial Statement Auditing Cycles                0
# 459       Case studies on credit appraisal for bankers                0
# 460                      Building a Balanced Scorecard                0
# 461  Options Trading Foundation: Your journey to co...                0
# 462  Forex how traders beat the markest with little...                0
# 463                  CFA Level 2- Quantitative Methods                0
# 464                           Foundations of Investing                0
# 785            Ratio Analysis for Financial Statements                0
# 784  Practical Film Financing: Finding & Pitching I...                0
# ...

# %%
top_15 = df_2.sort_values(by="num_subscribers", ascending=False).head(15)
top_15
# Out:
#                                            course_title  num_subscribers  \
# 2827               Learn HTML5 Programming From Scratch           268923
# 3032                     Coding for Entrepreneurs Basic           161029
# 3230                         The Web Developer Bootcamp           121584
# 2783  Build Your First Website in 1 Week with HTML5 ...           120291
# 3232              The Complete Web Developer Course 2.0           114512
# 1896              Free Beginner Electric Guitar Lessons           101154
# 2589  Web Design for Web Developers: Build Beautiful...            98867
# 2619             Learn Javascript & JQuery From Scratch            84897
# 3289  Practical PHP: Master the Basics and Code Dyna...            83737
# 3247          JavaScript: Understanding the Weird Parts            79612
# 1979  Pianoforall - Incredible New Way To Learn Pian...            75499
# 3204  Angular 4 (formerly Angular 2) - The Complete ...            73783
# ...
